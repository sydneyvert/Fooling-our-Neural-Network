# %%
import numpy
import keras

from keras.models import Sequential
from keras.layers import Dense

numpy.random.seed(0xC0FFEE)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Loading data

# %% [markdown]
# Run the below code to download a copy of the dataset (if you don't already have it):

# %%
import requests
import io
import zipfile

response = requests.get("http://www.schonlau.net/masquerade/masquerade-data.zip")
dataset_file = io.BytesIO(downloaded_dataset.content)
zipped_dataset = zipfile.ZipFile(dataset_file)
zipped_dataset.extractall('data/masquerade-data')

# %%
# http://www.schonlau.net/intrusion.html
# download Masquerade Data (zip File)

import pandas as pd
import os
directory = './data/masquerade-data'

# %%
import re
def sorted_nicely( l ):
    """ Sorts the given iterable in the way that is expected.
 
    Required arguments:
    l -- The iterable to be sorted.
 
    """
    convert = lambda text: int(text) if text.isdigit() else text
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)', key)]
    return sorted(l, key = alphanum_key)

# %%
users = range(1,51)
df = pd.DataFrame()

for filename in sorted_nicely(os.listdir(directory)):
    user = pd.read_csv(os.path.join(directory, filename), header=None)
    df = pd.concat([df, user], axis = 1)
    
df.columns = sorted_nicely(os.listdir(directory))

# %%
df
# Out:
#           User1     User2     User3     User4     User5     User6     User7  \
# 0           cpp       cat  Xsession       cat       cpp       cpp       cpp
# 1            sh      stty       sed      mail        sh        sh        sh
# 2          xrdb        ls  Xsession       csh      xrdb      xrdb      xrdb
# 3           cpp        ls       sed  toolches     mkpts     mkpts       cpp
# 4            sh        ls      grep        sh      test  hostname        sh
# 5          xrdb        ls        wc        rm  hostname       awk      xrdb
# 6         mkpts        ls      date        sh      stty      stty     mkpts
# 7           env  xdvi.rea     uname  MediaMai      date      tset      test
# 8           csh      xdvi     uname        ls      echo       env      stty
# 9           csh       cat     uname       cpp         [       ksh  hostname
# 10          csh        ls     uname        sh      find       ksh      date
# 11           sh     dvips      true      xrdb     chmod   userenv      echo
# 12          csh        gs  xsetroot     mkpts      echo   wait4wm         [
# 13         kill  ghostvie       cpp       env       env     xhost      find
# 14      userenv        gs        sh       csh      echo  xsetroot     chmod
# 15      wait4wm  ghostvie      xrdb       csh        sh    reaper       tty
# 16        xhost        gs       cat       csh   userenv       cat      echo
# 17     xsetroot  ghostvie     uname   userenv   wait4wm  hostname       env
# 18       reaper  emacs-20     uname        sh     xhost       awk      echo
# 19          cat        ls     uname       csh  xsetroot      stty        sh
# 20         mail        ls     uname      kill    reaper      tset   userenv
# 21          csh        gs      stty   wait4wm      4Dwm  launchef   wait4wm
# 22     launchef  ghostvie      stty     xhost         [        sh     xhost
# 23           sh       cat  basename  xsetroot       cat  launchef  xsetroot
# 24     launchef    virtex       ksh    reaper  hostname  hostname    reaper
# 25     hostname    virtex       sed       cat      stty       cat   xmodmap
# 26          cat     dvips      grep      mail      date  hostname        sh
# 27         mail        rm       sed       csh      echo       awk         [
# 28          csh  xdvi.rea      tail  launchef         [      stty       cat
# 29     launchef        gs       ksh        sh      find      tset      stty
# ...         ...       ...       ...       ...       ...       ...       ...
# 14970  sendmail       ld_   dirname        sh   getpgrp        sh        id
# 14971        sh        nm      java      more      LOCK    engine      nawk
# 14972  MediaMai        ld      java        sh      true        sh    getopt
# 14973  sendmail       gcc     javac      more        ls    engine      true
# 14974        ls       gcc        rm        sh       sed        sh      true
# 14975    virtex      make  .java_wr        ls      FIFO    engine      grep
# 14976        ls      flex      expr        sh       cat        sh      date
# 14977        rm     uname      expr      more      date    engine        lp
# 14978    virtex      nawk   dirname        sh   generic        sh      find
# 14979        rm       cpp  basename        ls   generic    engine      expr
# 14980        ls       cc1     egrep        sh      date        sh   generic
# 14981        ln        as     egrep      more   generic    engine       cat
# 14982        ls       gcc     egrep        sh   gethost        sh      file
# 14983        ls       gcc     egrep       csh  download    engine      post
# 14984    virtex     uname      expr        sh  tcpostio  basename       awk
# 14985     dvips      nawk      expr        rm  tcpostio        ln       cat
# 14986        ls       ld_      expr  MediaMai  tcpostio  purify.s      post
# 14987      true        nm      expr  sendmail  tcpostio        sh        rm
# 14988  basename        ld   dirname  sendmail       cat      make   generic
# 14989        gs       gcc      java        sh   generic       cal        ln
# 14990        ls       gcc      java  MediaMai        ls      tput        ln
# 14991  acroread      make     javac  sendmail   generic   rtslave   generic
# 14992  acroread     mkpts        rm        sh      date   rtslave        lp
# 14993  acroread     bison  .java_wr        rm   generic   rtslave        sh
# 14994      expr     bison      expr  MediaMai        rm        ex        sh
# 14995       cat     uname      expr       cat        ls      expr   getpgrp
# 14996  acroread      nawk   dirname      mail       sed      expr      LOCK
# 14997     uname       cpp  basename       csh      FIFO   dirname      LOCK
# 14998     uname       cc1     egrep  toolches        rm      fecc   generic
# 14999  acroread       gcc     egrep        sh    UNLOCK        be   tcppost
#
#           User8     User9    User10    ...       User41    User42    User43  \
# 0           cpp       cpp       cat    ...          cpp       cpp       cpp
# 1            sh        sh      mail    ...           sh        sh        sh
# 2          xrdb      xrdb      tcsh    ...         xrdb      xrdb      xrdb
# 3         mkpts       cpp      tcsh    ...          cpp       cpp     mkpts
# 4           env        sh       cat    ...           sh        sh      stty
# 5           ksh      xrdb      mail    ...         xrdb      xrdb      tset
# 6           ksh     mkpts      tcsh    ...        mkpts     mkpts     chmod
# 7       userenv  hostname        sh    ...     hostname  hostname     uname
# 8       wait4wm      date  sendmail    ...         stty       awk       cpp
# 9         xhost       env  sendmail    ...          env      stty        sh
# 10     xsetroot      tcsh        sh    ...         tcsh      tset      xrdb
# 11       reaper      tcsh  MediaMai    ...         tcsh     chmod       env
# 12          cat      tcsh  sendmail    ...         tcsh      news       ksh
# 13        touch        sh     sleep    ...           sh       env       ksh
# 14        mkdir      tcsh        sh    ...         tcsh       ksh   userenv
# 15     sendmail      kill        sh    ...         kill        rm   wait4wm
# 16         Mail   userenv        rm    ...      userenv       ksh     xhost
# 17          ksh   wait4wm  MediaMai    ...      wait4wm   userenv  xsetroot
# 18          frm     xhost        ls    ...        xhost   wait4wm    reaper
# 19           ls  xsetroot        ls    ...     xsetroot     xhost       cat
# 20     sendmail    reaper       pwd    ...       reaper  xsetroot      stty
# 21         Mail       cat        ls    ...          cat    reaper      tset
# 22          frm      mail   whereis    ...         mail       cat     chmod
# 23          ksh      tcsh    unpack    ...         tcsh  hostname     uname
# 24          ksh  hostname       col    ...     hostname       awk       cpp
# 25        touch    resize        ul    ...         stty      stty        sh
# 26       telnet      date      more    ...     launchef      tset      xrdb
# 27          ksh  launchef        sh    ...     launchef     chmod  launchef
# 28        help2  launchef       man    ...           sh      news        sh
# 29          ksh        sh       man    ...          cpp  launchef  launchef
# ...         ...       ...       ...    ...          ...       ...       ...
# 14970    popper      xrdb  comp_uni    ...           lp  purify.s  launchef
# 14971    popper       cpp        sh    ...      getpgrp        sh        sh
# 14972    popper        sh  m3_binin    ...         LOCK      make  launchef
# 14973    popper      xrdb     uname    ...         true        ex        sh
# 14974    popper     mkpts     uname    ...           ls      expr        sh
# 14975    popper  hostname  m3_compt    ...          sed      expr        rm
# 14976    popper      date       cfe    ...         FIFO   dirname  MediaMai
# 14977    popper       env      ugen    ...          cat      fecc  sendmail
# 14978    popper      tcsh       as1    ...         date        be  sendmail
# 14979    popper      tcsh    driver    ...      generic    driver        sh
# 14980    popper      tcsh  comp_uni    ...      generic  purify.s  MediaMai
# 14981    popper      tcsh        sh    ...         date        sh  sendmail
# 14982    popper        sh  m3_binin    ...      generic      make        ls
# 14983    popper      kill     uname    ...      gethost        ex        ls
# 14984    popper   userenv     uname    ...     download      expr      more
# 14985    popper   wait4wm  m3_compt    ...     tcpostio      expr        rm
# 14986    popper     xhost       cfe    ...     tcpostio   dirname      more
# 14987    popper  xsetroot      ugen    ...     tcpostio      fecc      more
# 14988    popper    reaper       as1    ...     tcpostio        be      more
# 14989    popper       cat    driver    ...          cat    driver  .java_wr
# 14990    popper      mail  comp_uni    ...      generic  purify.s      expr
# 14991    popper      tcsh        sh    ...           ls        sh      expr
# 14992    popper  hostname  m3_binin    ...      generic      make   dirname
# 14993    popper    resize     uname    ...         date      make  basename
# 14994    popper      date     uname    ...      generic        ex     egrep
# 14995    popper  launchef  m3_compt    ...           rm      expr     egrep
# 14996    popper  launchef       cfe    ...           ls      expr     egrep
# 14997    popper        sh      ugen    ...          sed   dirname     egrep
# 14998    popper        sh       as1    ...         FIFO      fecc      java
# 14999  hostname  sendmail    driver    ...           rm    driver      java
#
#          User44    User45    User46    User47    User48    User49    User50
# 0           cpp  hostname       cpp       cat       cat     touch       cpp
# 1            sh       cat        sh       cat        id        sh        sh
# 2          xrdb  .xsessio      xrdb      date    whoami  appdefpa      xrdb
# 3           cpp       sed       cpp       cat    telnet       cpp     mkpts
# 4            sh       cat        sh       cat       ksh        sh       env
# 5          xrdb  .xsessio      xrdb      date       cpp      xrdb       ksh
# 6         mkpts       sed     mkpts     flock        sh     sleep       ksh
# 7          stty  hostname  hostname      tcsh      xrdb    reaper   userenv
# 8          tset      stty      date   keep_up     mkpts        sh   wait4wm
# 9           env     touch      stty        sh       env     sleep     xhost
# 10         tcsh     chmod       env     flock       ksh     sleep  xsetroot
# 11         tcsh     touch      tcsh      tcsh       ksh      xset    reaper
# 12      userenv  appdefpa      tcsh   keep_up   userenv  xsetroot       cat
# 13         tcsh       cpp      tcsh        sh   wait4wm        sh  launchef
# 14         tcsh        sh        sh  htn_repo     xhost         z        sh
# 15           sh      xrdb      tcsh       sed  xsetroot        sh  launchef
# 16         kill       cpp      kill       cat    reaper    xclock  hostname
# 17      wait4wm        sh   userenv  htn_repo      4Dwm     faces       cat
# 18        xhost      xrdb   wait4wm  print_do       cat      4Dwm  launchef
# 19     xsetroot   xmodmap     xhost   findobj  launchef    xclock  launchef
# 20       reaper     xhost  xsetroot  print_us  launchef       xdm        sh
# 21          cat  xsetroot    reaper     egrep        sh        sh  hostname
# 22         mail    reaper       cat       ksh  hostname        rm       cat
# 23         tcsh  .xsessio      mail      tcsh       cat  MediaMai  launchef
# 24         stty        sh      tcsh       cat    passwd  appdefpa  launchef
# 25         tset      test  hostname      nawk        ls       cpp        sh
# 26         mail     uname    resize       cat    finger        sh        sh
# 27     sendmail      test      date      nawk     mkdir      xrdb  sendmail
# 28     sendmail      test      stty     egrep        ls    reaper  sendmail
# 29     sendmail        wc  launchef       tee    rlogin        sh        sh
# ...         ...       ...       ...       ...       ...       ...       ...
# 14970        gs   xupdate  sendmail     my.ls   generic        rm        ls
# 14971  ghostvie       pwd  sendmail      nawk      date        rm  launchef
# 14972      mail        ls        sh        ls   generic        ls  launchef
# 14973      tput        sh  MediaMai      date   gethost        mc        sh
# 14974        pq      find  sendmail      date  download        lc  hostname
# 14975        pq        sh        ls        ls  tcpostio        rm       cat
# 14976        ex      find      tcsh      nawk  tcpostio        sh      mail
# 14977    virtex        sh       cat     my.ls  tcpostio        rm      tcsh
# 14978     dvips      find  stream_t      nawk  tcpostio  MediaMai  hostname
# 14979  hostname        sh  call_fil        ls       cat        sh      date
# 14980        id      find   overlap      date   generic         z        ls
# 14981      nawk        sh     msort      date        ls        sh      more
# 14982    getopt  netscape      tcsh        ls   generic        rm        sh
# 14983      true  netscape       cat      nawk      date        sh      Mail
# 14984      true  netscape      sort     my.ls   generic  MediaMai     uname
# 14985      true  netscape      tcsh      nawk        rm        sh       cat
# 14986      grep  netscape       cat        ls        ls     xprop  PLATFORM
# 14987      date  netscape      grep      date       sed       xdm  Slmhelpe
# 14988        lp  netscape       sed      date      FIFO      4Dwm        sh
# 14989      find     mailx      tcsh        ls        rm    xclock        sh
# 14990      expr     mailx       cat      nawk    UNLOCK    xclock     egrep
# 14991   generic     mailx      grep     my.ls     rmdir     faces       sed
# 14992       cat     mailx       sed      nawk   generic      xwsh        sh
# 14993      file  netscape      tcsh        ls   tcppost        sh        sh
# 14994      post   xupdate       cat      date        sh      xwsh        sh
# 14995       awk       pwd      grep      date      LOCK        sh        sh
# 14996       cat       cat       sed        ls    rlogin  xmineswe        sh
# 14997      post     x3270      tcsh      nawk    rlogin  appdefpa        rm
# 14998        rm     x3270       cat     my.ls        ls       cpp      Mail
# 14999   generic     x3270      grep      nawk        ls        sh        ex
#
# [15000 rows x 50 columns]

# %%
train, test = df.head(501), df.tail(len(df) - 501)

# %% [markdown]
# ## Generate a Random Dataset
#
# Make up a silly dataset to make sure the oracle model expects the right thing.

# %%
commands = [
    '=',
    '==',
    '[',
    '1.1',
    '1.2',
    '1.3',
    '4Dwm',
    '5650.exe',
    '5836.exe',
    '7105.exe',
    '7956.exe',
    '8117.exe',
    '8708.exe',
    '9term',
    'aacdec',
    'aa.new.n',
    'aa.new.s',
    'accesspo',
    'acc.prof',
    'acroread',
    'addrinfo',
    'admin',
    'agrep',
    'aiffplay',
    'ama.chec',
    'ama_volu',
    'a.out',
    'apanel',
    'appdefpa',
    'ar',
    'arch',
    'Archie',
    'arch_uni',
    'arp',
    'array_te',
    'as',
    'as1',
    'ascii',
    'a.sl',
    'at',
    'augment_',
    'aupanel',
    'auplay',
    'aus',
    'autoconf',
    'awk',
    'awk.html',
    'backtalk',
    '%backup%',
    'banner',
    'basename',
    'bash',
    'BATCH',
    'bb_rep',
    'bb_rep_f',
    'bb_rep_n',
    'bb_rep_t',
    'bc',
    'bdftopcf',
    'bdiff',
    'be',
    'bibtex',
    'bindkey',
    'bind_so_',
    'bind_uni',
    'binhex',
    'bison',
    'blossom4',
    'bo_rep',
    'bo_rep_c',
    'bo_rep_f',
    'bo_rep_t',
    'bo_table',
    'bo_top',
    'bo_type',
    'btbuild',
    'btcreat',
    'byte_rev',
    'cal',
    'calendar',
    'calldd',
    'call_fil',
    'calprog',
    'cancel',
    'capture',
    'cat',
    'catalog',
    'catdoc',
    'CC',
    'cc1',
    'cdc',
    'cdec',
    'cfe',
    'c++filt',
    'cgiparse',
    'chat.awk',
    'chkconfi',
    'chmod',
    'chown',
    'ci',
    'cled',
    'cled_jct',
    'clock',
    'cmex',
    'cmp',
    'co',
    'col',
    'colthloo',
    'colthrea',
    'comm',
    'comma.te',
    'compress',
    'comp_uni',
    'concorde',
    'config.g',
    'config.s',
    'configur',
    'Configur',
    'conftest',
    'convert',
    'c++patch',
    'cpeek',
    'cpio',
    'cplex',
    'cpp',
    'crnl',
    'crontab',
    'crypt',
    'csh',
    'ctags',
    'cut',
    'cxwsh',
    'data_cl.',
    'date',
    'date-dif',
    'dbl',
    'dbx',
    'dbxpcs',
    'dc',
    'DC-prn',
    'dd',
    'ddd',
    'ddtest',
    'dec',
    'define',
    'delatex',
    'delta',
    'demo',
    'deroff',
    'desktopM',
    'detail_o',
    'detex',
    'dev.moti',
    'dev.post',
    'dev.X11',
    'df',
    'dialog.s',
    'dict',
    'diff',
    'dig',
    'dirname',
    'doc2ps',
    'doctype',
    'do.hourl',
    'domainna',
    'do.priso',
    'dot',
    'do.trit',
    'download',
    'dpost',
    'dprog',
    'drag',
    'drag2',
    'drawgrap',
    'drf',
    'drill_do',
    'driver',
    'driverwr',
    'ds_ar',
    'du',
    'dummy',
    'dvipost',
    'dvips',
    'dviselec',
    'e',
    'echo',
    'ed',
    'edgcpfe',
    'edgegen',
    'edg_prel',
    'efm',
    'egrep',
    'elm',
    'emacs-20',
    'emrvol',
    'enc',
    'endsessi',
    'engine',
    'enscript',
    'env',
    'eptofax',
    'eqn',
    'etags',
    'euphony',
    'euphony3',
    'ex',
    'expr',
    'expreser',
    'exrecove',
    'extract_',
    'f',
    'f2ps',
    'fa.booku',
    'faces',
    'fa.click',
    'false',
    'fastmail',
    'fcom',
    'fec',
    'fecc',
    'fgrep',
    'field',
    'FIFO',
    'fig2dev',
    'file',
    'find',
    'findobj',
    'find_RT',
    'finger',
    'fish2',
    'fish4',
    'flex',
    'flock',
    'flog',
    'flow',
    'fls_star',
    'fm',
    'fmarch',
    'fm_flb',
    'fm_misd',
    'fmprintd',
    'fmt',
    'fold',
    'foo',
    'force_up',
    'format.d',
    'frm',
    'ftp',
    'ftp.orig',
    'fvwm',
    'FvwmPage',
    'fx',
    'fxfilter',
    'fxprint',
    'fxsend',
    'fxshut',
    'fxstat',
    'fxstatus',
    'fxvision',
    'gawk',
    'gcc',
    'gdb',
    'gdiff',
    'generic',
    'gengraph',
    'get',
    'get_acc',
    'get_acc_',
    'getans',
    'getconf',
    'gethost',
    'get_line',
    'get.line',
    'getopt',
    'getpgrp',
    'getsampl',
    'gettxt',
    'gftopk',
    'ghostvie',
    'giftrans',
    'gimp',
    'gmake',
    'gnudiff',
    'gnuplot',
    'gnuplot_',
    'GoodStuf',
    'gordon',
    'gp',
    'gramlx',
    'graph_te',
    'gre',
    'grep',
    'groups',
    'gr_top',
    'gs',
    'gs3.33',
    'gsftopk',
    'gv',
    'gzip',
    'head',
    'heartche',
    'help',
    'help2',
    'help.fin',
    'help.key',
    'help.sor',
    'help.top',
    'hexbin',
    'hightoll',
    'hilow',
    'hinv',
    'hippo',
    'history',
    'hist_tes',
    'hoc',
    'host',
    'hostname',
    'hpost',
    'ht',
    'htn_date',
    'htn_edit',
    'htn_repo',
    'hype',
    'ico',
    'id',
    'identify',
    'imake',
    'imgview',
    'inc',
    'indent',
    'info',
    'infocmp',
    'init_src',
    'inline',
    'install-',
    'interest',
    'ipeek',
    'ispell',
    'j11',
    'jar',
    'java',
    'javac',
    '.java_wr',
    'join',
    'jot',
    'jre',
    'justlex',
    'justspec',
    'keep_up',
    'kill',
    'killall',
    'kludgepl',
    'kmist',
    'ksh',
    'last',
    'lattice_',
    'launchef',
    'lc',
    'lcc',
    'ld',
    'ld_',
    'ld64_',
    'lec2.awk',
    'lec.awk',
    'led',
    'less',
    'lex',
    'lex.spec',
    'line.pro',
    'lint',
    'lint1',
    'lint2',
    'list2.pl',
    'list.pl',
    'lks',
    'lmstat',
    'ln',
    'lo',
    'local.Sq',
    'LOCK',
    'logname',
    'long',
    'lp',
    'lp2col',
    'lpdsend',
    'lpe3',
    'lp.orig',
    'lpq',
    'lpr',
    'lps',
    'ls',
    'm',
    'm3_binin',
    'm3_compt',
    'm3_flsd',
    'm3_flse',
    'm3_manfl',
    'm4',
    'macunpac',
    'magma.ex',
    'mail',
    'Mail',
    'mailbox',
    'mailp',
    'mailx',
    'Main',
    'make',
    'make_del',
    'make_hig',
    'makeinde',
    'maker5X.',
    '.maker_w',
    'MakeTeXP',
    'make_tod',
    'makexgvi',
    'man',
    'maple.sy',
    'mapleTTY',
    'mars.sh',
    'matlab',
    'matlab_l',
    'mbackup',
    'mc',
    'MediaMai',
    'mesg',
    'metamail',
    'mhl',
    'mhn',
    'mi',
    'mimencod',
    'mkdir',
    'mkfontdi',
    'mklink.s',
    'mkpts',
    'more',
    'Mosaic',
    'movemail',
    'moviepla',
    'mp',
    'mpeg_pla',
    'mplotcha',
    'mplotps',
    'mplottek',
    'mplotx11',
    'msort',
    'munpack',
    'mycut',
    'mycut2',
    'my.ls',
    'my.ls.2',
    'my.ls.re',
    'mysql',
    'mysqladm',
    'mysql_in',
    'mywsh',
    'named',
    'nawk',
    'ncdquery',
    'neato',
    'nedit',
    'neqn',
    'netscape',
    'netstat',
    'newalias',
    'newmail',
    'news',
    'nfsstat',
    'nice',
    'nlcrack',
    'nlcrack2',
    'nlgen',
    'nlx',
    'nly',
    'nlz',
    'nlz2',
    'nm',
    'nm_elf',
    'nohup',
    'nospool',
    'npasplit',
    'nr',
    'nroff',
    'nscal',
    'ns-insta',
    'nslookup',
    'ntrim',
    'ntrim.in',
    'nw_8s_un',
    'od',
    'OLI.sh',
    'on',
    'one.awk',
    'op_cvmod',
    'op_mko',
    'op_mksim',
    'opnet',
    'op_newus',
    'op_runsi',
    'orig',
    'orig_sca',
    'overlap',
    'overlap2',
    'p',
    '=p',
    'pacdec',
    'pagemail',
    'panel_te',
    'passwd',
    'paste',
    'patch',
    'payphone',
    'pcst',
    'pcst1',
    'pcst.pur',
    'pdf2ps',
    'pdftops',
    'perl',
    'pftp',
    'pg',
    'pine',
    'ping',
    'plaid',
    'PLATFORM',
    'point.sh',
    'polar',
    'popper',
    'post',
    'postprin',
    'postreve',
    'pow',
    'ppost',
    'ppq',
    'ppqcomma',
    'pq',
    'pr',
    'prefix',
    'print_ca',
    'print_de',
    'print_do',
    'printf',
    'printreq',
    'print_sc',
    'print_us',
    'prisoncs',
    'prison_f',
    'prison_p',
    'prison_r',
    'profile',
    'ps',
    'ps2epsi',
    'ps2pdf',
    'psnr',
    'psu',
    'ptelnet',
    'punlx',
    'purify.s',
    'pwd',
    'q_eg',
    'q_egtest',
    'qk',
    'qpage',
    'q_test',
    'quota',
    'r',
    'R',
    'random_t',
    'randseq',
    'rbnull',
    'rcc',
    'rcp',
    'rcsdiff',
    'rdistd',
    'readacct',
    'readmsg',
    'reaper',
    'red',
    'Reducyr',
    'register',
    'renice',
    'req.new',
    'resize',
    'reverse',
    'rexecd',
    'rftp',
    'richtext',
    'rlogin',
    'rm',
    'rmail',
    'rmdir',
    'rmm',
    'rootless',
    'rpcinfo',
    'rsh',
    'rshd',
    'rtslave',
    'runnit',
    'run_swin',
    'rup',
    'ruptime',
    'rusers',
    'rvplayer',
    'rwho',
    'rz',
    'S',
    'sam',
    'sample',
    'samterm',
    'sar',
    'scampdet',
    'scamp_fi',
    'scamp_pr',
    'scamp_to',
    'scan',
    'scatter_',
    'sccs',
    'scheme',
    'scp',
    'scroll_t',
    'sd',
    'sdec',
    'sdlgMoti',
    'sed',
    'seecalls',
    'seediff',
    'see_scam',
    'sendmail',
    'seq',
    'setup',
    'sfplay',
    'sfstdgen',
    'sgihelp',
    'sgo',
    'sh',
    'shar',
    'shelpMot',
    'show',
    'showcal',
    'showdoc',
    'show_fil',
    'showfile',
    'shownona',
    'showprod',
    'showps',
    'sim301bK',
    'sim301bS',
    'Sizup',
    'sleep',
    'slide',
    'Slmclien',
    'Slmhelpe',
    'slogin',
    'sort',
    'soundpla',
    'soxpand',
    'spec',
    'spell',
    'split',
    'splitmai',
    'sprog',
    'Sqpe',
    'sqp_fill',
    'Squirrel',
    'ssh',
    'ssh-add',
    'ssh-agen',
    'ssh-askp',
    'ssh-keyg',
    'ssplay',
    'states',
    'Stat_Ind',
    'std_date',
    'stream_b',
    'stream_t',
    'strings',
    'stripper',
    'stty',
    'style1',
    'style2',
    'style3',
    'su',
    'suepope4',
    'sum',
    'summary.',
    'swap',
    'sysinfo',
    'sz',
    't',
    'tail',
    'talk',
    'tar',
    'tbl',
    'tcm',
    'tcm5na',
    'tcm8',
    'tcm8a',
    'tcm8na',
    'tcpostio',
    'tcppost',
    'tcsh',
    'tee',
    'tektroni',
    'tel',
    'tellwm',
    'telnet',
    'telno',
    'tes',
    'test',
    'test2.pl',
    'tester',
    'testFont',
    'testHist',
    'test.m2.',
    'test.pl',
    'text_are',
    'tftp',
    'tifftofa',
    'time',
    'toolches',
    'top',
    'touch',
    'tput',
    'tr',
    'tracerou',
    'Tracy',
    'trn',
    'troff',
    'true',
    'tset',
    'ttcm',
    'ttcm8',
    'tty',
    'twm',
    'twoprint',
    'ugen',
    'ul',
    'uname',
    'uniq',
    'UNLOCK',
    'unpack',
    'unzip',
    'uopt',
    'update',
    'use_abus',
    'userenv',
    'uudecode',
    'uuencode',
    'uuname',
    'v10sort',
    'vacation',
    'vc',
    'vim',
    'vinay',
    'vipw',
    'virmf',
    'virtex',
    'vis',
    'volumes.',
    'vreg',
    'vsimsg',
    'vsiupdst',
    'vt100',
    'vtwm',
    'w',
    'W',
    'w3c',
    'wait4wm',
    'wc',
    'wdefine',
    'webify',
    'webmagic',
    'what',
    'where',
    'whereis',
    'which',
    'who',
    'whoami',
    'whodo',
    'whois',
    'windows',
    'window_t',
    'winterm',
    'worklist',
    '.wrapper',
    'X',
    'x11perf',
    'x3270',
    'xargs',
    'xauth',
    'xbiff',
    'xcal',
    'xcalc',
    'xcalenda',
    'xclock',
    'xconfirm',
    'xdemineu',
    'xdiff',
    'xdm',
    'xdpyinfo',
    'xdvi',
    'xdvi.rea',
    'xemacs-1',
    'xemacs-2',
    'xev',
    'xfig',
    'xfontsel',
    'xfs',
    'xgas',
    'xgobi',
    'xgvis',
    'xhost',
    '.xinitrc',
    'xinitrem',
    'xlbiff',
    'xlistscr',
    'xload',
    'xloadima',
    'xlsclien',
    'xlsfonts',
    'xmag',
    'xman',
    'xmaplev4',
    'xmaplev5',
    'xmessage',
    'xmh',
    'xmineswe',
    'xmkmf',
    'xmodmap',
    'xpaint',
    'xpdf',
    'xpr',
    'xprop',
    'xrdb',
    'Xremote',
    'xrn',
    'xrt_auth',
    'xrtld',
    '.xsessio',
    'Xsession',
    'xset',
    'xsetroot',
    'xt',
    'xterm',
    'xupdate',
    'xv',
    'xwd',
    'xwininfo',
    'xwsh',
    'xxx',
    'yacc',
    'ypcat',
    'yppasswd',
    'z',
    'zip',
    'zsh',
    'zubs',
    'zz2',
]

num_commands = len(commands)
num_commands
# Out:
# 856

# %%
raw_training_data =  numpy.random.randint(
    low=1, 
    high=50, 
    size=(7500, num_commands),
)
raw_training_labels =  numpy.random.randint(
    low=1, 
    high=50, 
    size=(7500, 1),
)

# %%
import pandas

training_labels =  keras.utils.to_categorical(raw_training_labels, num_classes=50)
training_dataset = pandas.DataFrame(raw_training_data, columns=commands)

# %%
training_dataset.describe()
# Out:
#                  =           ==            [          1.1          1.2  \
# count  7500.000000  7500.000000  7500.000000  7500.000000  7500.000000
# mean     24.862267    24.912400    25.157333    25.019067    25.072800
# std      14.084966    14.068648    14.179607    14.180660    14.109285
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      13.000000    13.000000    13.000000    13.000000    13.000000
# 50%      25.000000    25.000000    25.000000    25.000000    25.000000
# 75%      37.000000    37.000000    37.000000    37.000000    37.000000
# max      49.000000    49.000000    49.000000    49.000000    49.000000
#
#                1.3         4Dwm     5650.exe     5836.exe     7105.exe  \
# count  7500.000000  7500.000000  7500.000000  7500.000000  7500.000000
# mean     24.778667    24.908533    24.991600    25.238933    24.859867
# std      14.155578    14.232891    13.997621    14.109330    14.145528
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      13.000000    13.000000    13.000000    13.000000    13.000000
# 50%      25.000000    25.000000    25.000000    25.000000    25.000000
# 75%      37.000000    37.000000    37.000000    38.000000    37.000000
# max      49.000000    49.000000    49.000000    49.000000    49.000000
#
#           ...            xwsh          xxx         yacc        ypcat  \
# count     ...       7500.0000  7500.000000  7500.000000  7500.000000
# mean      ...         25.1560    24.684267    24.866667    24.918800
# std       ...         14.2073    14.198234    14.060964    14.215652
# min       ...          1.0000     1.000000     1.000000     1.000000
# 25%       ...         13.0000    12.000000    13.000000    13.000000
# 50%       ...         25.0000    24.000000    25.000000    25.000000
# 75%       ...         37.0000    37.000000    37.000000    37.000000
# max       ...         49.0000    49.000000    49.000000    49.000000
#
#           yppasswd            z          zip          zsh         zubs  \
# count  7500.000000  7500.000000  7500.000000  7500.000000  7500.000000
# mean     25.020133    24.947333    24.781200    25.058667    25.122133
# std      14.161038    14.121008    14.091806    14.157517    14.091599
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      13.000000    13.000000    13.000000    13.000000    13.000000
# 50%      25.000000    25.000000    25.000000    25.000000    25.000000
# 75%      37.000000    37.000000    37.000000    37.000000    37.000000
# max      49.000000    49.000000    49.000000    49.000000    49.000000
#
#                zz2
# count  7500.000000
# mean     25.375333
# std      14.131167
# min       1.000000
# 25%      13.000000
# 50%      25.000000
# 75%      38.000000
# max      49.000000
#
# [8 rows x 856 columns]

# %% [markdown]
# # Building the Oracle

# %%
oracle = Sequential()

# %%
input_layer = Dense(
    units=856,
    activation='relu',
    input_dim=856,
)

# %%
hidden_layer = Dense(
    units=30,
    activation='relu',
)

# %%
output_layer = Dense(
    units=50,
    activation='sigmoid',
)

# %%
oracle.add(input_layer)
oracle.add(hidden_layer)
oracle.add(output_layer)

# %%
oracle.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy'],
)

# %% [markdown]
# # Running oracle on Dataset

# %%
oracle.fit(training_dataset,  training_labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 7500/7500 [==============================] - 5s 706us/step - loss: 9.2178 - acc: 0.0228
# Epoch 2/10
# 7500/7500 [==============================] - 5s 640us/step - loss: 9.2269 - acc: 0.0224
# Epoch 3/10
# 7500/7500 [==============================] - 5s 648us/step - loss: 9.2269 - acc: 0.0224
# Epoch 4/10
# 7500/7500 [==============================] - 5s 655us/step - loss: 9.2269 - acc: 0.0224
# Epoch 5/10
# 7500/7500 [==============================] - 5s 651us/step - loss: 9.2269 - acc: 0.0224
# Epoch 6/10
# 7500/7500 [==============================] - 5s 640us/step - loss: 9.2269 - acc: 0.0224
# Epoch 7/10
# 7500/7500 [==============================] - 5s 629us/step - loss: 9.2269 - acc: 0.0224
# Epoch 8/10
# 7500/7500 [==============================] - 5s 637us/step - loss: 9.2269 - acc: 0.0224
# Epoch 9/10
# 7500/7500 [==============================] - 5s 637us/step - loss: 9.2269 - acc: 0.0224
# Epoch 10/10
# 7500/7500 [==============================] - 5s 625us/step - loss: 9.2269 - acc: 0.0224

# %%
oracle

# %%
score = oracle.evaluate(training_dataset, training_labels)
# Out:
# 7500/7500 [==============================] - 1s 152us/step

# %%
score
# Out:
# [9.226850337219238, 0.0224]

# %%
oracle.metrics_names
# Out:
# ['loss', 'acc']
